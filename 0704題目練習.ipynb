# %%
#nums=[1,2,1]
def a(nums):
 n=len(nums)
 ans=[0]*(2*n)

 for i in range(n):
    ans[i]=nums[i]
    ans[i+n]=nums[i]
 print(ans)

a([1,3,2,1])
# Out:
# [1, 3, 2, 1, 1, 3, 2, 1]

# %%
nums=[2,5,1,3,4,7]
k=3
n=len(nums)

ans=[0]*(n)
for i in range(k):
  ans[2*i]=nums[i]
  ans[2*i+1]=nums[i+3]
print(ans)
# Out:
# [2, 3, 5, 4, 1, 7]

# %%
#nums=[1,1,2,2]
#n=2
def a(nums , n):
 ans=[]
 for i in range(n):
   ans.append(nums[i])
   ans.append(nums[i+n])
 print(ans)

a([1,1,2,2],2)
# Out:
# [1, 2, 1, 2]
